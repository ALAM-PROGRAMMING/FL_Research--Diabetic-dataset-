# %% [markdown]
# 1. Environment Setup

# %%
import pandas as pd
import numpy as np

np.random.seed(42)

# %% [markdown]
# 2. Load Raw Data

# %%
us_path = "../data/raw/diabetes_binary_health_indicators_BRFS.csv"
india_path = "../data/raw/diabetes_prediction_india (1).csv"

df_us = pd.read_csv(us_path)
df_india = pd.read_csv(india_path)

print("US Shape:", df_us.shape)
print("India Shape:", df_india.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 us_path = "../data/raw/diabetes_binary_health_indicators_BRFS.csv"
#       2 india_path = "../data/raw/diabetes_prediction_india (1).csv"
# ----> 4 df_us = pd.read_csv(us_path)
#       5 df_india = pd.read_csv(india_path)
#       7 print("US Shape:", df_us.shape)
#
# File c:\Users\Haripriya\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Haripriya\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\Haripriya\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Haripriya\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\Haripriya\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/raw/diabetes_binary_health_indicators_BRFS.csv'

# %%
us_path = "../data/raw/diabetes_binary_health_indicators_BRFS.csv"
india_path = "../data/raw/diabetes_prediction_india (1).csv"

df_us = pd.read_csv(us_path)
df_india = pd.read_csv(india_path)

print("US Dataset Shape:", df_us.shape)
print("India Dataset Shape:", df_india.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 us_path = "../data/raw/diabetes_binary_health_indicators_BRFS.csv"
#       2 india_path = "../data/raw/diabetes_prediction_india (1).csv"
# ----> 4 df_us = pd.read_csv(us_path)
#       5 df_india = pd.read_csv(india_path)
#       7 print("US Dataset Shape:", df_us.shape)
#
# File c:\Users\Haripriya\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Haripriya\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\Haripriya\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Haripriya\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\Haripriya\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/raw/diabetes_binary_health_indicators_BRFS.csv'

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\Haripriya\Desktop\PROJECT\FL_Research\1_data_pipeline

# %%
import os

print(os.listdir("../data/raw"))
# Out:
# ['diabetes_binary_health_indicators_BRFSS2015.csv', 'diabetes_prediction_india (1).csv', 'RAW_DATA_HERE']

# %%
us_path = "../data/raw/diabetes_binary_health_indicators_BRFSS2015.csv"
india_path = "../data/raw/diabetes_prediction_india (1).csv"

df_us = pd.read_csv(us_path)
df_india = pd.read_csv(india_path)

print("US Dataset Shape:", df_us.shape)
print("India Dataset Shape:", df_india.shape)
# Out:
# US Dataset Shape: (253680, 22)
# India Dataset Shape: (5292, 27)

# %% [markdown]
#  3. Column Extraction

# %%
us_columns = [
    "Diabetes_012", "Age", "Sex", "BMI", "HighBP",
    "HighChol", "Smoker", "HvyAlcoholConsump",
    "PhysActivity", "AnyHealthcare"
]

india_columns = [
    "Diabetes_Status", "Age", "Gender", "BMI",
    "Hypertension", "Cholesterol_Level",
    "Smoking_Status", "Alcohol_Intake",
    "Physical_Activity", "Health_Insurance"
]

df_us = df_us[us_columns]
df_india = df_india[india_columns]

print("US Shape After Filtering:", df_us.shape)
print("India Shape After Filtering:", df_india.shape)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 14
#       1 us_columns = [
#       2     "Diabetes_012", "Age", "Sex", "BMI", "HighBP",
#       3     "HighChol", "Smoker", "HvyAlcoholConsump",
#       4     "PhysActivity", "AnyHealthcare"
#       5 ]
#       7 india_columns = [
#       8     "Diabetes_Status", "Age", "Gender", "BMI",
#       9     "Hypertension", "Cholesterol_Level",
#      10     "Smoking_Status", "Alcohol_Intake",
#      11     "Physical_Activity", "Health_Insurance"
#      12 ]
# ---> 14 df_us = df_us[us_columns]
#      15 df_india = df_india[india_columns]
#      17 print("US Shape After Filtering:", df_us.shape)
#
# File c:\Users\Haripriya\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Haripriya\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Haripriya\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Diabetes_012'] not in index"

# %%
print("US Columns:")
print(df_us.columns.tolist())

print("\nIndia Columns:")
print(df_india.columns.tolist())
# Out:
# US Columns:
# ['Diabetes_binary', 'HighBP', 'HighChol', 'CholCheck', 'BMI', 'Smoker', 'Stroke', 'HeartDiseaseorAttack', 'PhysActivity', 'Fruits', 'Veggies', 'HvyAlcoholConsump', 'AnyHealthcare', 'NoDocbcCost', 'GenHlth', 'MentHlth', 'PhysHlth', 'DiffWalk', 'Sex', 'Age', 'Education', 'Income']
#
# India Columns:
# ['Age', 'Gender', 'BMI', 'Family_History', 'Physical_Activity', 'Diet_Type', 'Smoking_Status', 'Alcohol_Intake', 'Stress_Level', 'Hypertension', 'Cholesterol_Level', 'Fasting_Blood_Sugar', 'Postprandial_Blood_Sugar', 'HBA1C', 'Heart_Rate', 'Waist_Hip_Ratio', 'Urban_Rural', 'Health_Insurance', 'Regular_Checkups', 'Medication_For_Chronic_Conditions', 'Pregnancies', 'Polycystic_Ovary_Syndrome', 'Glucose_Tolerance_Test_Result', 'Vitamin_D_Level', 'C_Protein_Level', 'Thyroid_Condition', 'Diabetes_Status']

# %%
us_columns = [
    "Diabetes_binary", "Age", "Sex", "BMI", "HighBP",
    "HighChol", "Smoker", "HvyAlcoholConsump",
    "PhysActivity", "AnyHealthcare"
]

india_columns = [
    "Diabetes_Status", "Age", "Gender", "BMI",
    "Hypertension", "Cholesterol_Level",
    "Smoking_Status", "Alcohol_Intake",
    "Physical_Activity", "Health_Insurance"
]

df_us = df_us[us_columns]
df_india = df_india[india_columns]

print("US Shape After Filtering:", df_us.shape)
print("India Shape After Filtering:", df_india.shape)
# Out:
# US Shape After Filtering: (253680, 10)
# India Shape After Filtering: (5292, 10)

# %% [markdown]
#  4. Rename India Columns

# %%
rename_mapping = {
    "Diabetes_Status": "Diabetes_binary",
    "Gender": "Sex",
    "Hypertension": "HighBP",
    "Cholesterol_Level": "HighChol",
    "Smoking_Status": "Smoker",
    "Alcohol_Intake": "HvyAlcoholConsump",
    "Physical_Activity": "PhysActivity",
    "Health_Insurance": "AnyHealthcare"
}

df_india.rename(columns=rename_mapping, inplace=True)

print("India columns renamed.")
print("\nIndia Columns After Rename:")
print(df_india.columns.tolist())
# Out:
# India columns renamed.
#
# India Columns After Rename:
# ['Diabetes_binary', 'Age', 'Sex', 'BMI', 'HighBP', 'HighChol', 'Smoker', 'HvyAlcoholConsump', 'PhysActivity', 'AnyHealthcare']

# %%
print("US Age unique values:")
print(sorted(df_us["Age"].unique()))

print("\nIndia Age min & max:")
print("Min:", df_india["Age"].min())
print("Max:", df_india["Age"].max())
# Out:
# US Age unique values:
# [np.float64(1.0), np.float64(2.0), np.float64(3.0), np.float64(4.0), np.float64(5.0), np.float64(6.0), np.float64(7.0), np.float64(8.0), np.float64(9.0), np.float64(10.0), np.float64(11.0), np.float64(12.0), np.float64(13.0)]
#
# India Age min & max:
# Min: 18
# Max: 79

# %% [markdown]
#  5. Align Age Buckets

# %%
def age_to_bucket(age):
    if age <= 24:
        return 1
    elif age <= 29:
        return 2
    elif age <= 34:
        return 3
    elif age <= 39:
        return 4
    elif age <= 44:
        return 5
    elif age <= 49:
        return 6
    elif age <= 54:
        return 7
    elif age <= 59:
        return 8
    elif age <= 64:
        return 9
    elif age <= 69:
        return 10
    elif age <= 74:
        return 11
    elif age <= 79:
        return 12
    else:
        return 13

# Apply only to India dataset
df_india["Age"] = df_india["Age"].apply(age_to_bucket)

print("Age alignment complete.")
print("India Age unique buckets:", sorted(df_india["Age"].unique()))
# Out:
# Age alignment complete.
# India Age unique buckets: [np.int64(1), np.int64(2), np.int64(3), np.int64(4), np.int64(5), np.int64(6), np.int64(7), np.int64(8), np.int64(9), np.int64(10), np.int64(11), np.int64(12)]

# %%
print("US Missing Values:")
print(df_us.isna().sum())

print("\nIndia Missing Values:")
print(df_india.isna().sum())
# Out:
# US Missing Values:
# Diabetes_binary      0
# Age                  0
# Sex                  0
# BMI                  0
# HighBP               0
# HighChol             0
# Smoker               0
# HvyAlcoholConsump    0
# PhysActivity         0
# AnyHealthcare        0
# dtype: int64
#
# India Missing Values:
# Diabetes_binary         0
# Age                     0
# Sex                     0
# BMI                     0
# HighBP                  0
# HighChol                0
# Smoker                  0
# HvyAlcoholConsump    1780
# PhysActivity            0
# AnyHealthcare           0
# dtype: int64

# %%
print("Unique values in India HvyAlcoholConsump:")
print(df_india["HvyAlcoholConsump"].unique())
# Out:
# Unique values in India HvyAlcoholConsump:
# <ArrowStringArray>
# [nan, 'Moderate', 'High']
# Length: 3, dtype: str

# %% [markdown]
# Encode HvyAlcoholConsump (India)

# %%
alcohol_mapping = {
    "Moderate": 0,
    "High": 1
}

df_india["HvyAlcoholConsump"] = df_india["HvyAlcoholConsump"].map(alcohol_mapping)

print("Alcohol column encoded.")
print(df_india["HvyAlcoholConsump"].unique())
# Out:
# Alcohol column encoded.
# [nan  0.  1.]

# %% [markdown]
#  6. Median Imputation

# %%
df_us = df_us.fillna(df_us.median(numeric_only=True))
df_india = df_india.fillna(df_india.median(numeric_only=True))

print("Missing values after imputation (India):")
print(df_india.isna().sum())
# Out:
# Missing values after imputation (India):
# Diabetes_binary      0
# Age                  0
# Sex                  0
# BMI                  0
# HighBP               0
# HighChol             0
# Smoker               0
# HvyAlcoholConsump    0
# PhysActivity         0
# AnyHealthcare        0
# dtype: int64

# %% [markdown]
#  7. Export Clean Datasets

# %%
df_us.to_csv("../data/processed/us_cleaned_aligned.csv", index=False)
df_india.to_csv("../data/processed/india_cleaned_aligned.csv", index=False)

print("Cleaned datasets exported successfully.")
# Out:
# Cleaned datasets exported successfully.

# %% [markdown]
# hari work done
